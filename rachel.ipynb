# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
import pandas as pd

# Load the data
player_data = pd.read_csv('./data/players.csv')
salary_data = pd.read_csv('./data/salaries_1985to2018.csv')

# %%
player_data.columns
player_data.info()
player_data.isnull().sum()
player_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4685 entries, 0 to 4684
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        4685 non-null   int64
#  1   _id          4685 non-null   object
#  2   birthDate    4657 non-null   object
#  3   birthPlace   4185 non-null   object
#  4   career_AST   4685 non-null   float64
#  5   career_FG%   4685 non-null   object
#  6   career_FG3%  3557 non-null   object
#  7   career_FT%   4685 non-null   object
#  8   career_G     4685 non-null   int64
#  9   career_PER   4685 non-null   object
#  10  career_PTS   4685 non-null   float64
#  11  career_TRB   4685 non-null   object
#  12  career_WS    4685 non-null   object
#  13  career_eFG%  3557 non-null   object
#  14  college      4372 non-null   object
#  15  draft_pick   3369 non-null   object
#  16  draft_round  3507 non-null   object
#  17  draft_team   3507 non-null   object
#  18  draft_year   3306 non-null   object
#  19  height       4685 non-null   object
#  20  highSchool   4025 non-null   object
#  21  name         4685 non-null   object
#  22  position     4685 non-null   object
#  23  shoots       4684 non-null   object
#  24  weight       4680 non-null   object
# dtypes: float64(2), int64(2), object(21)
# memory usage: 915.2+ KB
#    index        _id         birthDate              birthPlace  career_AST  \
# 0      0  abdelal01     June 24, 1968            Cairo, Egypt         0.3
# 1      1  abdulza01     April 7, 1946      Brooklyn, New York         1.2
# 2      2  abdulka01    April 16, 1947      New York, New York         3.6
# 3      3  abdulma02     March 9, 1969   Gulfport, Mississippi         3.5
# 4      4  abdulta01  November 3, 1974  Maisons Alfort, France         1.1
#
#   career_FG% career_FG3% career_FT%  career_G career_PER  ...    draft_pick  \
# 0       50.2         0.0       70.1       256       13.0  ...  25th overall
# 1       42.8         NaN       72.8       505       15.1  ...   5th overall
# 2       55.9         5.6       72.1      1560       24.6  ...   1st overall
# 3       44.2        35.4       90.5       586       15.4  ...   3rd overall
# 4       41.7        23.7       70.3       236       11.4  ...  11th overall
#
#   draft_round              draft_team draft_year height  \
# 0   1st round  Portland Trail Blazers       1990   6-10
# 1   1st round       Cincinnati Royals       1968    6-9
# 2   1st round         Milwaukee Bucks       1969    7-2
# 3   1st round          Denver Nuggets       1990    6-1
# 4   1st round        Sacramento Kings       1997    6-6
#
#                                 highSchool                 name  \
# 0     Bloomfield in Bloomfield, New Jersey       Alaa Abdelnaby
# 1           John Jay in Brooklyn, New York      Zaid Abdul-Aziz
# 2     Power Memorial in New York, New York  Kareem Abdul-Jabbar
# 3        Gulfport in Gulfport, Mississippi   Mahmoud Abdul-Rauf
# 4  Lycee Aristide Briand in Evreux, France    Tariq Abdul-Wahad
#
#                    position shoots weight
# 0             Power Forward  Right  240lb
# 1  Power Forward and Center  Right  235lb
# 2                    Center  Right  225lb
# 3               Point Guard  Right  162lb
# 4            Shooting Guard  Right  223lb
#
# [5 rows x 25 columns]

# %%
salary_data.columns
# Out:
# Index(['index', 'league', 'player_id', 'salary', 'season', 'season_end',
#        'season_start', 'team'],
#       dtype='object')

# %%
player_data.columns
# Out:
# Index(['index', '_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight'],
#       dtype='object')

# %%
salary_data.head(10)
# Out:
#    index league  player_id   salary   season  season_end  season_start  \
# 0      0    NBA  abdelal01   395000  1990-91        1991          1990
# 1      1    NBA  abdelal01   494000  1991-92        1992          1991
# 2      2    NBA  abdelal01   500000  1992-93        1993          1992
# 3      3    NBA  abdelal01   805000  1993-94        1994          1993
# 4      4    NBA  abdelal01   650000  1994-95        1995          1994
# 5      5    NBA  abdulka01  1530000  1984-85        1985          1984
# 6      6    NBA  abdulka01  2030000  1985-86        1986          1985
# 7      7    NBA  abdulka01  2000000  1987-88        1988          1987
# 8      8    NBA  abdulka01  3000000  1988-89        1989          1988
# 9      9    NBA  abdulma02  1660000  1990-91        1991          1990
#
#                      team
# 0  Portland Trail Blazers
# 1  Portland Trail Blazers
# 2          Boston Celtics
# 3          Boston Celtics
# 4        Sacramento Kings
# 5      Los Angeles Lakers
# 6      Los Angeles Lakers
# 7      Los Angeles Lakers
# 8      Los Angeles Lakers
# 9          Denver Nuggets

# %%
print(salary_data['league'].value_counts())
print(salary_data['team'].value_counts())
# Out:
# league
# NBA    14163
# Name: count, dtype: int64
# team
# Philadelphia 76ers                   519
# Dallas Mavericks                     519
# Phoenix Suns                         509
# Houston Rockets                      509
# Los Angeles Clippers                 503
# Boston Celtics                       502
# New York Knicks                      499
# Chicago Bulls                        496
# Atlanta Hawks                        494
# Cleveland Cavaliers                  491
# Golden State Warriors                491
# Milwaukee Bucks                      491
# Denver Nuggets                       490
# San Antonio Spurs                    488
# Portland Trail Blazers               487
# Indiana Pacers                       484
# Sacramento Kings                     482
# Detroit Pistons                      481
# Los Angeles Lakers                   475
# Orlando Magic                        463
# Utah Jazz                            456
# Miami Heat                           453
# Minnesota Timberwolves               436
# New Jersey Nets                      413
# Toronto Raptors                      375
# Washington Wizards                   346
# Seattle SuperSonics                  308
# Memphis Grizzlies                    298
# Charlotte Hornets                    253
# Oklahoma City Thunder                163
# Charlotte Bobcats                    156
# Washington Bullets                   153
# New Orleans Hornets                  143
# Brooklyn Nets                        103
# New Orleans Pelicans                  95
# Vancouver Grizzlies                   93
# New Orleans/Oklahoma City Hornets     31
# Kansas City Kings                     11
# Name: count, dtype: int64

# %%
print(player_data['position'].value_counts())
print(player_data['college'].value_counts())
# Out:
# position
# Shooting Guard                                                        679
# Center                                                                613
# Small Forward                                                         611
# Point Guard                                                           584
# Power Forward                                                         521
# Point Guard and Shooting Guard                                        177
# Guard                                                                 163
# Center and Power Forward                                              162
# Forward                                                               162
# Power Forward and Center                                              161
# Shooting Guard and Point Guard                                        143
# Power Forward and Small Forward                                       134
# Shooting Guard and Small Forward                                      128

# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.histplot(player_data['career_PTS'], kde=True, color='blue', bins=20)
plt.title('Distribution of Career Points')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(salary_data['salary'], kde=True, color='green', bins=20)
plt.title('Distribution of Salary')
plt.show()

# %%
plt.figure(figsize=(12,6))
avg_salary_team = salary_data.groupby('team')['salary'].mean().sort_values(ascending=False)
sns.barplot(x=avg_salary_team.index, y=avg_salary_team.values, palette='viridis')
plt.xticks(rotation=90)
plt.title('Average Salary by Team')
plt.xlabel('Team')
plt.ylabel('Average Salary')
plt.show()
# Out:
# /var/folders/mx/kjgrsg2j30b4r2hppnttbh840000gn/T/ipykernel_4890/3749719351.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_salary_team.index, y=avg_salary_team.values, palette='viridis')

# %%
plt.figure(figsize=(10,6))
sns.histplot(player_data['career_PTS'], kde=True, color='green', bins=30)
plt.title('Distribution of Career Points')
plt.xlabel('Career Points')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='height', y='career_PTS', data=player_data, color='orange')
plt.title('Height vs Career Points')
plt.xlabel('Height (in inches)')
plt.ylabel('Career Points')
plt.show()

# %% [markdown]
# **DATA CLEANING**

# %%
player_data.dropna(inplace = True)
player_data = player_data.drop(columns = 'index')
player_data.describe()
# Out:
#         career_AST     career_G   career_PTS
# count  2360.000000  2360.000000  2360.000000
# mean      1.670805   371.894492     7.529364
# std       1.524798   336.238378     5.035131
# min       0.000000     1.000000     0.000000
# 25%       0.600000    74.750000     3.500000
# 50%       1.200000   272.000000     6.400000
# 75%       2.200000   620.500000    10.300000
# max      11.200000  1611.000000    30.100000

# %%
player_data['draft_year'] = player_data['draft_year'].astype(int)
player_data = player_data[player_data['draft_year']>= 2000]
player_data['draft_year'].min()
# Out:
# 2000

# %%
salary_data = salary_data[salary_data['season_start']>= 2000]
salary_data['season_start'].min()
# Out:
# 2000

# %%
salary_data.dropna(inplace = True)
player_data.dropna(inplace = True)
#salary_data = salary_data.drop(columns = 'index') #
player_data.head()
# Out:
#           _id         birthDate             birthPlace  career_AST career_FG%  \
# 10  ackeral01  January 21, 1983    Compton, California         0.5       37.0
# 14    acyqu01   October 6, 1990           Tyler, Texas         0.6       44.4
# 18  adamsha01     June 20, 1984  Inglewood, California         0.2       53.4
# 20  adamsjo01      July 8, 1994       Atlanta, Georgia         0.6       40.2
# 22  adamsst01     July 20, 1993   Rotorua, New Zealand         1.0       58.8
#
#    career_FG3% career_FT%  career_G career_PER  career_PTS  ...    draft_pick  \
# 10        32.0       50.0        30        8.5         2.7  ...  60th overall
# 14        35.0       75.9       337       11.2         4.9  ...  37th overall
# 18         0.0       64.3        73       11.8         2.5  ...  54th overall
# 20        38.5       60.7        32       13.1         3.2  ...  22nd overall
# 22         0.0       55.3       467       16.7         9.7  ...  12th overall
#
#    draft_round             draft_team draft_year height  \
# 10   2nd round        Detroit Pistons       2005    6-5
# 14   2nd round        Toronto Raptors       2012    6-7
# 18   2nd round        New Jersey Nets       2006    6-4
# 20   1st round      Memphis Grizzlies       2014    6-5
# 22   1st round  Oklahoma City Thunder       2013    7-0
#
#                                            highSchool          name  \
# 10                   Eisenhower in Rialto, California    Alex Acker
# 14                   Mesquite Horn in Mesquite, Texas    Quincy Acy
# 18             Westchester in Los Angeles, California  Hassan Adams
# 20      Oak Hill Academy in Mouth of Wilson, Virginia  Jordan Adams
# 22  Notre Dame Preparatory School in Fitchburg, Ma...  Steven Adams
#
#                            position shoots weight
# 10                   Shooting Guard  Right  185lb
# 14  Power Forward and Small Forward  Right  240lb
# 18                   Shooting Guard  Right  220lb
# 20                   Shooting Guard  Right  209lb
# 22                           Center  Right  265lb
#
# [5 rows x 24 columns]

# %%
print(merged_data['draft_team'].unique())
print(merged_data['team'].unique())
# Out:
# [nan 'Detroit Pistons' 'Toronto Raptors' 'Brooklyn Nets'
#  'Memphis Grizzlies' 'Oklahoma City Thunder' 'Miami Heat'
#  'Dallas Mavericks' 'New Orleans Hornets' 'Chicago Bulls' 'Orlando Magic'
#  'Milwaukee Bucks' 'Utah Jazz' 'Boston Celtics' 'Philadelphia 76ers'
#  'Los Angeles Clippers' 'San Antonio Spurs' 'Indiana Pacers'
#  'Denver Nuggets' 'Golden State Warriors' 'New York Knicks'
#  'Houston Rockets' 'Charlotte Bobcats' 'Phoenix Suns'
#  'Minnesota Timberwolves' 'New Orleans Pelicans' 'Sacramento Kings'
#  'Los Angeles Lakers' 'Portland Trail Blazers' 'Washington Wizards'
#  'Atlanta Hawks' 'Cleveland Cavaliers' 'Vancouver Grizzlies']
# ['Vancouver Grizzlies' 'Denver Nuggets' 'Dallas Mavericks' 'Atlanta Hawks'
#  'Portland Trail Blazers' 'Sacramento Kings' 'Oklahoma City Thunder'
#  'Detroit Pistons' 'Los Angeles Clippers' 'Toronto Raptors'
#  'New York Knicks' 'Brooklyn Nets' 'Memphis Grizzlies' 'Miami Heat'
#  'Golden State Warriors' 'Houston Rockets' 'Charlotte Bobcats'
#  'Orlando Magic' 'Minnesota Timberwolves' 'San Antonio Spurs'
#  'New Orleans Pelicans' 'Philadelphia 76ers' 'Washington Wizards'
#  'New Orleans Hornets' 'Milwaukee Bucks' 'Chicago Bulls' nan
#  'Indiana Pacers' 'Boston Celtics' 'Utah Jazz' 'Phoenix Suns'
#  'Cleveland Cavaliers' 'Los Angeles Lakers']

# %%
merged_data['draft_team'] = merged_data['draft_team'].replace({
    'Seattle SuperSonics': 'Oklahoma City Thunder', 
    'Charlotte Hornets': 'New Orleans Hornets', 
    'New Orleans/Oklahoma City Hornets': 'New Orleans Hornets', 
    'New Jersey Nets': 'Brooklyn Nets'
    })

merged_data['team'] = merged_data['team'].replace({
    'Seattle SuperSonics': 'Oklahoma City Thunder', 
    'Charlotte Hornets': 'New Orleans Hornets', 
    'New Orleans/Oklahoma City Hornets': 'New Orleans Hornets', 
    'New Jersey Nets': 'Brooklyn Nets'
    })

# %%
merged_data.columns
# Out:
# Index(['player_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight', 'league', 'salary', 'season',
#        'season_end', 'season_start', 'team'],
#       dtype='object')

# %%
train_data = merged_data[(merged_data['season_start']>=2000) & (merged_data['season_end']<=2012)]
test_data = merged_data[merged_data['season_end']>2012]

# %%
train_data.to_csv('data/train_data.csv', index=False)
test_data.to_csv('data/test_data.csv', index=False)

# %% [markdown]
# **MODELS**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.preprocessing import LabelEncoder

# %%
merged_data.columns
# Out:
# Index(['player_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight', 'league', 'salary', 'season',
#        'season_end', 'season_start', 'team'],
#       dtype='object')

# %%
df = merged_data.dropna(subset=['salary'])
threshold = 0.8  # Threshold for missing values
df = df.dropna(thresh=int(threshold * len(df_cleaned)), axis=1)
df = df.drop(columns=['player_id', 'season_start', 'season_end', 'season', 'league'])

# %%
print(df)
# Out:
#          salary                 team
# 0      798500.0  Vancouver Grizzlies
# 1     4500000.0       Denver Nuggets
# 2     5062500.0       Denver Nuggets
# 3     5625000.0     Dallas Mavericks
# 4     6187500.0     Dallas Mavericks
# ...         ...                  ...
# 8840   750000.0        Chicago Bulls
# 8841  1312611.0        Chicago Bulls
# 8842  1645200.0  Cleveland Cavaliers
# 8843  1034956.0   Los Angeles Lakers
# 8844  1312611.0   Los Angeles Lakers
#
# [8770 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['salary', 'team'], dtype='object')

# %%
X = df.drop(columns=['salary'])  # All columns except 'salary' are features
y = df['salary']

# %%
X_encoded = pd.get_dummies(X, drop_first=True)  # One-Hot Encoding

# %% [markdown]
# **FORWARD STEPWISE SELECTION**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit and transform the data
df_standardized = scaler.fit_transform(X_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
from sklearn.feature_selection import SequentialFeatureSelector

# %%
model = LinearRegression()

# Forward stepwise selection
sfs = SequentialFeatureSelector(model, n_features_to_select="auto", direction="forward")
sfs.fit(X_train, y_train)

selected_features = X_train.columns[sfs.get_support()]
print("Selected features using Forward Stepwise Selection:", selected_features)

final_model = LinearRegression()
final_model.fit(X_train[selected_features], y_train)

from sklearn.metrics import mean_squared_error, r2_score

y_pred = final_model.predict(X_test[selected_features])
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Selected features using Forward Stepwise Selection: Index(['team_Brooklyn Nets', 'team_Charlotte Bobcats',
#        'team_Cleveland Cavaliers', 'team_Dallas Mavericks',
#        'team_Houston Rockets', 'team_Los Angeles Lakers',
#        'team_Memphis Grizzlies', 'team_Minnesota Timberwolves',
#        'team_New Orleans Hornets', 'team_New York Knicks',
#        'team_Philadelphia 76ers', 'team_Portland Trail Blazers',
#        'team_Sacramento Kings', 'team_Vancouver Grizzlies',
#        'team_Washington Wizards'],
#       dtype='object')
# Mean Squared Error: 23372651081379.95
# R-squared: -0.002613660406151741

# %% [markdown]
# **BACKWARD STEPWISE SELECTION**

# %%
model = LinearRegression()

# Backward stepwise selection
sfs_backward = SequentialFeatureSelector(model, n_features_to_select="auto", direction="backward")
sfs_backward.fit(X_train, y_train)

selected_features_backward = X_train.columns[sfs_backward.get_support()]
print("Selected features using Backward Stepwise Selection:", selected_features_backward)

final_model_backward = LinearRegression()
final_model_backward.fit(X_train[selected_features_backward], y_train)

y_pred_backward = final_model_backward.predict(X_test[selected_features_backward])
mse_backward = mean_squared_error(y_test, y_pred_backward)
r2_backward = r2_score(y_test, y_pred_backward)

print(f"Mean Squared Error (Backward Selection): {mse_backward}")
print(f"R-squared (Backward Selection): {r2_backward}")
# Out:
# Selected features using Backward Stepwise Selection: Index(['team_Brooklyn Nets', 'team_Charlotte Bobcats',
#        'team_Cleveland Cavaliers', 'team_Dallas Mavericks',
#        'team_Houston Rockets', 'team_Los Angeles Lakers',
#        'team_Memphis Grizzlies', 'team_Minnesota Timberwolves',
#        'team_New Orleans Hornets', 'team_New York Knicks',
#        'team_Orlando Magic', 'team_Philadelphia 76ers',
#        'team_Portland Trail Blazers', 'team_Sacramento Kings',
#        'team_Vancouver Grizzlies', 'team_Washington Wizards'],
#       dtype='object')
# Mean Squared Error (Backward Selection): 23371996965955.812
# R-squared (Backward Selection): -0.002585600899447149

# %% [markdown]
# **DATA FROM REGRESSION MODEL**

# %%
# Combine the data based on player_id and _id
combined_data = pd.merge(player_data, salary_data, left_on='_id', right_on='player_id')

combined_data.head()

# Get highest season end
highest_season_end = salary_data['season_end'].max()
highest_season_end

# Filter the data to only season_end > 2010
recent_data = combined_data[combined_data['season_end'] > 2010]

career_earnings = salary_data[["player_id", "salary"]].groupby("player_id").sum()
career_earnings.head()

career_player_data = player_data.join(career_earnings, on="_id")
career_player_data["draft_pick"].head()

career_player_data["draft_pick_num"] = career_player_data["draft_pick"].replace(r"\D+", "", regex=True)
career_player_data["draft_pick_num"] = pd.to_numeric(career_player_data["draft_pick_num"])
career_player_data["draft_pick_num"].head()

# Create column if player position was "Power Forward and Small Forward and Shooting Guard"
career_player_data["is_combo_position"] = career_player_data["position"] == ("Power Forward and Small Forward and Shooting Guard")
career_player_data["is_combo_position"].head()

import seaborn as sns
import numpy as np

# Make a column for each position they played
career_player_data["is_power_forward"] = career_player_data["position"].str.contains("Power Forward")
career_player_data["is_small_forward"] = career_player_data["position"].str.contains("Small Forward")
career_player_data["is_shooting_guard"] = career_player_data["position"].str.contains("Shooting Guard")
career_player_data["is_center"] = career_player_data["position"].str.contains("Center")
career_player_data["is_point_guard"] = career_player_data["position"].str.contains("Point Guard")


career_player_data[["name", "position", "is_power_forward", "is_small_forward", "is_shooting_guard", "is_center", "is_point_guard"]].head()

# find players who are power forward, small forward, and shooting guards

career_player_data[(career_player_data["is_power_forward"] & career_player_data["is_small_forward"] & career_player_data["is_shooting_guard"])]


# %%
# Show average salary for each position by binary position
career_player_data.groupby("is_power_forward")["salary"].mean()
career_player_data.groupby("is_small_forward")["salary"].mean()
career_player_data.groupby("is_shooting_guard")["salary"].mean()
career_player_data.groupby("is_center")["salary"].mean()
career_player_data.groupby("is_point_guard")["salary"].mean()

# %% [markdown]
# ## Regression Model

# %%
# Make a column for each position they played
combined_data["is_power_forward"] = combined_data["position"].str.contains("Power Forward")
combined_data["is_small_forward"] = combined_data["position"].str.contains("Small Forward")
combined_data["is_shooting_guard"] = combined_data["position"].str.contains("Shooting Guard")
combined_data["is_center"] = combined_data["position"].str.contains("Center")
combined_data["is_point_guard"] = combined_data["position"].str.contains("Point Guard")

# %%
combined_data.columns

# %%
# Create dummy variables for team
team_dummies = pd.get_dummies(combined_data["team"])

# Combine the data
combined_data = pd.concat([combined_data, team_dummies], axis=1)
combined_data.head()

# %%
# SHow types of columns

player_data.dtypes

# %%
# Convert all columns to numeric

combined_data = combined_data.apply(pd.to_numeric, errors='coerce')


# %%
combined_data.head()

# %%
pd.options.display.max_rows = 4000

# %%
# Show columns with NaN values

combined_data.isna().sum()

# %%
# Create df with only ['season_end', 'team', 'is_power_forward', 'is_small_forward',
    #    'is_shooting_guard', 'is_center', 'is_point_guard', 'career_AST', 'career_FG%',
    #    'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
    #    'career_TRB', 'career_WS', 'career_eFG%',] and team_dummies

refined_data = combined_data[['salary', 'season_end', 'is_power_forward', 'is_small_forward',
         'is_shooting_guard', 'is_center', 'is_point_guard', 'career_AST', 'career_FG%',
         'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
         'career_TRB', 'career_WS', 'career_eFG%'] + list(team_dummies.columns)]


refined_data = refined_data.dropna()

refined_data.shape

refined_data.head()
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
refined_data.columns
# Out:
# Index(['salary', 'season_end', 'is_power_forward', 'is_small_forward',
#        'is_shooting_guard', 'is_center', 'is_point_guard', 'career_AST',
#        'career_FG%', 'career_FG3%', 'career_FT%', 'career_G', 'career_PER',
#        'career_PTS', 'career_TRB', 'career_WS', 'career_eFG%', 'Atlanta Hawks',
#        'Boston Celtics', 'Brooklyn Nets', 'Charlotte Bobcats',
#        'Charlotte Hornets', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons',
#        'Golden State Warriors', 'Houston Rockets', 'Indiana Pacers',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies',
#        'Miami Heat', 'Milwaukee Bucks', 'Minnesota Timberwolves',
#        'New Jersey Nets', 'New Orleans Hornets', 'New Orleans Pelicans',
#        'New Orleans/Oklahoma City Hornets', 'New York Knicks',
#        'Oklahoma City Thunder', 'Orlando Magic', 'Philadelphia 76ers',
#        'Phoenix Suns', 'Portland Trail Blazers', 'Sacramento Kings',
#        'San Antonio Spurs', 'Seattle SuperSonics', 'Toronto Raptors',
#        'Utah Jazz', 'Vancouver Grizzlies', 'Washington Wizards'],
#       dtype='object')

# %% [markdown]
# **LASSO**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import numpy as np

# Assuming you have your data in a pandas DataFrame `df`
# Replace this with loading your actual data, e.g., df = pd.read_csv('data.csv')

# Separate the target variable (salary) from the predictors
X = refined_data.drop('salary', axis=1)
y = refined_data['salary']

# One-hot encode categorical columns (e.g., team names)
X = pd.get_dummies(X, columns=['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets', 
                               'Charlotte Bobcats', 'Charlotte Hornets', 'Chicago Bulls',
                               'Cleveland Cavaliers', 'Dallas Mavericks', 'Denver Nuggets',
                               'Detroit Pistons', 'Golden State Warriors', 'Houston Rockets',
                               'Indiana Pacers', 'Los Angeles Clippers', 
                               'Los Angeles Lakers', 'Memphis Grizzlies', 'Miami Heat',
                               'Milwaukee Bucks', 'Minnesota Timberwolves', 'New Jersey Nets', 
                               'New Orleans Hornets', 'New Orleans Pelicans', 'New Orleans/Oklahoma City Hornets',
                               'New York Knicks', 'Oklahoma City Thunder', 'Orlando Magic',
                               'Philadelphia 76ers', 'Phoenix Suns', 'Portland Trail Blazers',
                               'Sacramento Kings', 'San Antonio Spurs', 'Seattle SuperSonics',
                               'Toronto Raptors', 'Utah Jazz', 'Vancouver Grizzlies', 'Washington Wizards'], drop_first=True)

# Standardize the predictors (Lasso is sensitive to the scale of the features)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize Lasso regression model with an alpha value (regularization strength)
lasso = Lasso(alpha=0.1)  # You may need to tune the alpha value

# Train the Lasso regression model
lasso.fit(X_train, y_train)

# Predict the salary on the test set
y_pred = lasso.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")\


r2_score = lasso.score(X_test, y_test)
print(f"R-squared (R²): {r2_score}")

# Optionally, you can check the coefficients of the features to understand the influence of each predictor
print("Lasso Coefficients:")
print(lasso.coef_)
# Out:
# Root Mean Squared Error (RMSE): 3825967.609726134
# R-squared (R²): 0.4407313182738509
# Lasso Coefficients:
# [1250277.34005673  -85206.96501008  106734.48063673  -70402.44618227
#   289955.95806672  -97207.27632363  111820.01835969  417528.01694837
#    -5350.41679597  -86550.21674492   51359.53449731 -310008.06239729
#  1266304.80596463  170094.17595658 2040655.83246968 -699321.56246949
#   -38650.3966238    49147.4854643   109148.49844894   40795.48754959
#    50856.62339501   18645.57542379   -3694.51717724  -75968.67876646
#    -7443.34590448    6586.82522327  -61850.97685641   -3537.60569962
#    53182.3601817     4813.88635244   15915.15159101  -19428.14857287
#     2930.2410423   138127.88971009  -58071.05240716   82340.56961259
#    -3880.43681269   87078.37436018  -59247.37100668  135683.23868633
#   -40114.07608643  -51017.64304332  -46578.559246    -94647.6867887
#   -21049.62659794 -108852.61536311   -7681.16428015   43080.46386314
#    16677.95405976  -40406.13703023   31911.42500939  100428.5566179 ]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.486e+14, tolerance: 7.216e+12
#   model = cd_fast.enet_coordinate_descent(
