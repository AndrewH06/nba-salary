# %%
import pandas as pd

# Load the data
player_data = pd.read_csv('./data/players.csv')
salary_data = pd.read_csv('./data/salaries_1985to2018.csv')

# %%
player_data.columns
player_data.info()
player_data.isnull().sum()
player_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4685 entries, 0 to 4684
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        4685 non-null   int64
#  1   _id          4685 non-null   object
#  2   birthDate    4657 non-null   object
#  3   birthPlace   4185 non-null   object
#  4   career_AST   4685 non-null   float64
#  5   career_FG%   4685 non-null   object
#  6   career_FG3%  3557 non-null   object
#  7   career_FT%   4685 non-null   object
#  8   career_G     4685 non-null   int64
#  9   career_PER   4685 non-null   object
#  10  career_PTS   4685 non-null   float64
#  11  career_TRB   4685 non-null   object
#  12  career_WS    4685 non-null   object
#  13  career_eFG%  3557 non-null   object
#  14  college      4372 non-null   object
#  15  draft_pick   3369 non-null   object
#  16  draft_round  3507 non-null   object
#  17  draft_team   3507 non-null   object
# ...

# %%
salary_data.columns
# Out:
# Index(['index', 'league', 'player_id', 'salary', 'season', 'season_end',
#        'season_start', 'team'],
#       dtype='object')

# %%
player_data.columns
# Out:
# Index(['index', '_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight'],
#       dtype='object')

# %%
salary_data.head(10)
# Out:
#    index league  player_id   salary   season  season_end  season_start  \
# 0      0    NBA  abdelal01   395000  1990-91        1991          1990
# 1      1    NBA  abdelal01   494000  1991-92        1992          1991
# 2      2    NBA  abdelal01   500000  1992-93        1993          1992
# 3      3    NBA  abdelal01   805000  1993-94        1994          1993
# 4      4    NBA  abdelal01   650000  1994-95        1995          1994
# 5      5    NBA  abdulka01  1530000  1984-85        1985          1984
# 6      6    NBA  abdulka01  2030000  1985-86        1986          1985
# 7      7    NBA  abdulka01  2000000  1987-88        1988          1987
# 8      8    NBA  abdulka01  3000000  1988-89        1989          1988
# 9      9    NBA  abdulma02  1660000  1990-91        1991          1990
#
#                      team
# 0  Portland Trail Blazers
# 1  Portland Trail Blazers
# 2          Boston Celtics
# 3          Boston Celtics
# 4        Sacramento Kings
# ...

# %%
print(salary_data['league'].value_counts())
print(salary_data['team'].value_counts())
# Out:
# league
# NBA    14163
# Name: count, dtype: int64
# team
# Philadelphia 76ers                   519
# Dallas Mavericks                     519
# Phoenix Suns                         509
# Houston Rockets                      509
# Los Angeles Clippers                 503
# Boston Celtics                       502
# New York Knicks                      499
# Chicago Bulls                        496
# Atlanta Hawks                        494
# Cleveland Cavaliers                  491
# Golden State Warriors                491
# Milwaukee Bucks                      491
# Denver Nuggets                       490
# San Antonio Spurs                    488
# Portland Trail Blazers               487
# Indiana Pacers                       484
# Sacramento Kings                     482
# Detroit Pistons                      481
# Los Angeles Lakers                   475
# Orlando Magic                        463
# Utah Jazz                            456
# ...

# %%
print(player_data['position'].value_counts())
print(player_data['college'].value_counts())
# Out:
# position
# Shooting Guard                                                        679
# Center                                                                613
# Small Forward                                                         611
# Point Guard                                                           584
# Power Forward                                                         521
# Point Guard and Shooting Guard                                        177
# Guard                                                                 163
# Center and Power Forward                                              162
# Forward                                                               162
# Power Forward and Center                                              161
# Shooting Guard and Point Guard                                        143
# Power Forward and Small Forward                                       134
# Shooting Guard and Small Forward                                      128
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.histplot(player_data['career_PTS'], kde=True, color='blue', bins=20)
plt.title('Distribution of Career Points')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(salary_data['salary'], kde=True, color='green', bins=20)
plt.title('Distribution of Salary')
plt.show()

# %%
plt.figure(figsize=(12,6))
avg_salary_team = salary_data.groupby('team')['salary'].mean().sort_values(ascending=False)
sns.barplot(x=avg_salary_team.index, y=avg_salary_team.values, palette='viridis')
plt.xticks(rotation=90)
plt.title('Average Salary by Team')
plt.xlabel('Team')
plt.ylabel('Average Salary')
plt.show()
# Out:
# /var/folders/mx/kjgrsg2j30b4r2hppnttbh840000gn/T/ipykernel_4890/3749719351.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_salary_team.index, y=avg_salary_team.values, palette='viridis')

# %%
plt.figure(figsize=(10,6))
sns.histplot(player_data['career_PTS'], kde=True, color='green', bins=30)
plt.title('Distribution of Career Points')
plt.xlabel('Career Points')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='height', y='career_PTS', data=player_data, color='orange')
plt.title('Height vs Career Points')
plt.xlabel('Height (in inches)')
plt.ylabel('Career Points')
plt.show()

# %%
player_data.dropna(inplace = True)
player_data = player_data.drop(columns = 'index')
player_data.describe()
# Out:
#         career_AST     career_G   career_PTS
# count  2360.000000  2360.000000  2360.000000
# mean      1.670805   371.894492     7.529364
# std       1.524798   336.238378     5.035131
# min       0.000000     1.000000     0.000000
# 25%       0.600000    74.750000     3.500000
# 50%       1.200000   272.000000     6.400000
# 75%       2.200000   620.500000    10.300000
# max      11.200000  1611.000000    30.100000

# %%
player_data['draft_year'] = player_data['draft_year'].astype(int)
player_data = player_data[player_data['draft_year']>= 2000]
player_data['draft_year'].min()
# Out:
# 2000

# %%
salary_data = salary_data[salary_data['season_start']>= 2000]
salary_data['season_start'].min()
# Out:
# 2000

# %%
salary_data.dropna(inplace = True)
player_data.dropna(inplace = True)
#salary_data = salary_data.drop(columns = 'index') #
player_data.head()
# Out:
#           _id         birthDate             birthPlace  career_AST career_FG%  \
# 10  ackeral01  January 21, 1983    Compton, California         0.5       37.0
# 14    acyqu01   October 6, 1990           Tyler, Texas         0.6       44.4
# 18  adamsha01     June 20, 1984  Inglewood, California         0.2       53.4
# 20  adamsjo01      July 8, 1994       Atlanta, Georgia         0.6       40.2
# 22  adamsst01     July 20, 1993   Rotorua, New Zealand         1.0       58.8
#
#    career_FG3% career_FT%  career_G career_PER  career_PTS  ...    draft_pick  \
# 10        32.0       50.0        30        8.5         2.7  ...  60th overall
# 14        35.0       75.9       337       11.2         4.9  ...  37th overall
# 18         0.0       64.3        73       11.8         2.5  ...  54th overall
# 20        38.5       60.7        32       13.1         3.2  ...  22nd overall
# 22         0.0       55.3       467       16.7         9.7  ...  12th overall
#
# ...

# %%
#player_data.rename(columns = {'_id':'player_id'}, inplace = True) #
merged_data = pd.merge(player_data, salary_data, on = 'player_id', how = 'outer')

merged_data.columns
# Out:
# Index(['player_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight', 'league', 'salary', 'season',
#        'season_end', 'season_start', 'team'],
#       dtype='object')

# %%
print(merged_data['draft_team'].unique())
print(merged_data['team'].unique())
# Out:
# [nan 'Detroit Pistons' 'Toronto Raptors' 'New Jersey Nets'
#  'Memphis Grizzlies' 'Oklahoma City Thunder' 'Miami Heat'
#  'Dallas Mavericks' 'New Orleans Hornets' 'Chicago Bulls' 'Orlando Magic'
#  'Milwaukee Bucks' 'Utah Jazz' 'Brooklyn Nets' 'Boston Celtics'
#  'Philadelphia 76ers' 'Los Angeles Clippers' 'San Antonio Spurs'
#  'Indiana Pacers' 'Denver Nuggets' 'Golden State Warriors'
#  'New York Knicks' 'Houston Rockets' 'New Orleans/Oklahoma City Hornets'
#  'Charlotte Bobcats' 'Phoenix Suns' 'Minnesota Timberwolves'
#  'New Orleans Pelicans' 'Sacramento Kings' 'Los Angeles Lakers'
#  'Portland Trail Blazers' 'Washington Wizards' 'Atlanta Hawks'
#  'Cleveland Cavaliers' 'Seattle SuperSonics' 'Charlotte Hornets'
#  'Vancouver Grizzlies']
# ['Vancouver Grizzlies' 'Denver Nuggets' 'Dallas Mavericks' 'Atlanta Hawks'
#  'Portland Trail Blazers' 'Sacramento Kings' 'Oklahoma City Thunder'
#  'Detroit Pistons' 'Los Angeles Clippers' 'Toronto Raptors'
# ...

# %%
merged_data['draft_team'] = merged_data['draft_team'].replace({
    'Seattle SuperSonics': 'Oklahoma City Thunder', 
    'Charlotte Hornets': 'New Orleans Hornets', 
    'New Orleans/Oklahoma City Hornets': 'New Orleans Hornets', 
    'New Jersey Nets': 'Brooklyn Nets'
    })

merged_data['team'] = merged_data['team'].replace({
    'Seattle SuperSonics': 'Oklahoma City Thunder', 
    'Charlotte Hornets': 'New Orleans Hornets', 
    'New Orleans/Oklahoma City Hornets': 'New Orleans Hornets', 
    'New Jersey Nets': 'Brooklyn Nets'
    })

# %%
merged_data.columns
# Out:
# Index(['player_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight', 'league', 'salary', 'season',
#        'season_end', 'season_start', 'team'],
#       dtype='object')

# %%
train_data = merged_data[(merged_data['season_start']>=2000) & (merged_data['season_end']<=2012)]
test_data = merged_data[merged_data['season_end']>2012]

# %%
train_data.to_csv('data/train_data.csv', index=False)
test_data.to_csv('data/test_data.csv', index=False)

# %%
numeric_data = merged_data.select_dtypes(include = ['number'])
numeric_data.hist(figsize=(10, 10), bins=10, grid=False)
plt.suptitle("Histograms of Numeric Columns")
plt.show()

# %%
plt.figure(figsize=(10, 5))
for column in numeric_data.columns:
    sns.kdeplot(merged_data[column], label=column, fill=True)
    plt.title("KDE Plots of Numeric Columns")
    plt.xlabel("Values")
    plt.ylabel("Density")
    plt.legend()
    plt.show()

# %%
corr_matrix = numeric_data.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(merged_data, hue="draft_round", diag_kind="kde") 
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.preprocessing import LabelEncoder

# %%
merged_data.columns
# Out:
# Index(['player_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight', 'league', 'salary', 'season',
#        'season_end', 'season_start', 'team'],
#       dtype='object')

# %%
df = merged_data.dropna(subset=['salary'])
threshold = 0.8  # Threshold for missing values
df = df.dropna(thresh=int(threshold * len(df_cleaned)), axis=1)
df = df.drop(columns=['player_id'])

# %%
df.head
# Out:
# <bound method NDFrame.head of      league     salary   season  season_end  season_start                 team
# 0       NBA   798500.0  2000-01      2001.0        2000.0  Vancouver Grizzlies
# 1       NBA  4500000.0  2000-01      2001.0        2000.0       Denver Nuggets
# 2       NBA  5062500.0  2001-02      2002.0        2001.0       Denver Nuggets
# 3       NBA  5625000.0  2002-03      2003.0        2002.0     Dallas Mavericks
# 4       NBA  6187500.0  2003-04      2004.0        2003.0     Dallas Mavericks
# ...     ...        ...      ...         ...           ...                  ...
# 8840    NBA   750000.0  2016-17      2017.0        2016.0        Chicago Bulls
# 8841    NBA  1312611.0  2017-18      2018.0        2017.0        Chicago Bulls
# 8842    NBA  1645200.0  2017-18      2018.0        2017.0  Cleveland Cavaliers
# 8843    NBA  1034956.0  2016-17      2017.0        2016.0   Los Angeles Lakers
# ...

# %%
X = df.drop(columns=['salary'])  # All columns except 'salary' are features
y = df['salary']

# %%
X_encoded = pd.get_dummies(X, drop_first=True)  # One-Hot Encoding
# Out:
# All columns are numeric.
# /var/folders/mx/kjgrsg2j30b4r2hppnttbh840000gn/T/ipykernel_4890/1633644589.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   if not np.all(X_encoded.applymap(np.isreal).all()):

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
from sklearn.feature_selection import SequentialFeatureSelector

# %%
model = LinearRegression()

# Forward stepwise selection
sfs = SequentialFeatureSelector(model, n_features_to_select="auto", direction="forward")
sfs.fit(X_train, y_train)

# Get the selected features
selected_features = X_train.columns[sfs.get_support()]
print("Selected features using Forward Stepwise Selection:", selected_features)

# Step 7: Fit the final model with the selected features
final_model = LinearRegression()
final_model.fit(X_train[selected_features], y_train)

# Step 8: Evaluate the model on the test set
from sklearn.metrics import mean_squared_error, r2_score

y_pred = final_model.predict(X_test[selected_features])
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Selected features using Forward Stepwise Selection: Index(['season_start', 'season_2001-02', 'season_2002-03', 'season_2007-08',
#        'season_2008-09', 'season_2009-10', 'season_2012-13', 'season_2014-15',
#        'season_2015-16', 'season_2016-17', 'season_2017-18',
#        'team_Brooklyn Nets', 'team_Charlotte Bobcats',
#        'team_Cleveland Cavaliers', 'team_Dallas Mavericks',
#        'team_Detroit Pistons', 'team_Los Angeles Lakers',
#        'team_Memphis Grizzlies', 'team_Milwaukee Bucks',
#        'team_New York Knicks', 'team_Orlando Magic',
#        'team_Portland Trail Blazers', 'team_Sacramento Kings',
#        'team_Vancouver Grizzlies', 'team_Washington Wizards'],
#       dtype='object')
# Mean Squared Error: 22862755484227.03
# R-squared: 0.019259266601847735

# %%
model = LinearRegression()

# Backward stepwise selection
sfs_backward = SequentialFeatureSelector(model, n_features_to_select="auto", direction="backward")
sfs_backward.fit(X_train, y_train)

# Get the selected features
selected_features_backward = X_train.columns[sfs_backward.get_support()]
print("Selected features using Backward Stepwise Selection:", selected_features_backward)

# Step 7: Fit the final model with the selected features
final_model_backward = LinearRegression()
final_model_backward.fit(X_train[selected_features_backward], y_train)

# Step 8: Evaluate the model on the test set
y_pred_backward = final_model_backward.predict(X_test[selected_features_backward])
mse_backward = mean_squared_error(y_test, y_pred_backward)
r2_backward = r2_score(y_test, y_pred_backward)

print(f"Mean Squared Error (Backward Selection): {mse_backward}")
print(f"R-squared (Backward Selection): {r2_backward}")
# Out:
# Selected features using Backward Stepwise Selection: Index(['season_start', 'season_2001-02', 'season_2002-03', 'season_2007-08',
#        'season_2008-09', 'season_2012-13', 'season_2014-15', 'season_2015-16',
#        'season_2016-17', 'season_2017-18', 'team_Brooklyn Nets',
#        'team_Charlotte Bobcats', 'team_Cleveland Cavaliers',
#        'team_Dallas Mavericks', 'team_Detroit Pistons',
#        'team_Los Angeles Clippers', 'team_Los Angeles Lakers',
#        'team_Memphis Grizzlies', 'team_Milwaukee Bucks',
#        'team_Minnesota Timberwolves', 'team_New York Knicks',
#        'team_Philadelphia 76ers', 'team_Portland Trail Blazers',
#        'team_Vancouver Grizzlies', 'team_Washington Wizards'],
#       dtype='object')
# Mean Squared Error (Backward Selection): 22876809189031.973
# R-squared (Backward Selection): 0.018656406602454156

# %%
# def best_subset_selection(X_train, y_train, X_test, y_test):
#     best_r2 = -np.inf  # Initialize the best R-squared score
#     best_subset = None  # Initialize the best feature subset
#     n_features = X_train.shape[1]

#     # Generate all possible feature subsets
#     for k in range(1, n_features + 1):
#         for subset in itertools.combinations(X_train.columns, k):
#             # Create a subset of the data
#             X_train_subset = X_train[list(subset)]
#             X_test_subset = X_test[list(subset)]

#             # Train the model
#             model = LinearRegression()
#             model.fit(X_train_subset, y_train)

#             # Evaluate the model
#             y_pred = model.predict(X_test_subset)
#             r2 = r2_score(y_test, y_pred)

#             # If the current subset is better, update the best subset and best R2
#             if r2 > best_r2:
#                 best_r2 = r2
#                 best_subset = subset

#     return best_subset, best_r2

# # Perform Best Subset Selection
# best_subset, best_r2 = best_subset_selection(X_train, y_train, X_test, y_test)

# print("Best feature subset:", best_subset)
# print("Best R-squared:", best_r2)

# # Step 7: Fit the final model with the selected features
# final_model_best_subset = LinearRegression()
# final_model_best_subset.fit(X_train[list(best_subset)], y_train)

# # Step 8: Evaluate the final model on the test set
# y_pred_best_subset = final_model_best_subset.predict(X_test[list(best_subset)])
# mse_best_subset = mean_squared_error(y_test, y_pred_best_subset)
# r2_best_subset = r2_score(y_test, y_pred_best_subset)

# print(f"Mean Squared Error (Best Subset Selection): {mse_best_subset}")
# print(f"R-squared (Best Subset Selection): {r2_best_subset}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[148], line 29
#      26     return best_subset, best_r2
#      28 # Perform Best Subset Selection
# ---> 29 best_subset, best_r2 = best_subset_selection(X_train, y_train, X_test, y_test)
#      31 print("Best feature subset:", best_subset)
#      32 print("Best R-squared:", best_r2)
#
# Cell In[148], line 8, in best_subset_selection(X_train, y_train, X_test, y_test)
#       6 # Generate all possible feature subsets
#       7 for k in range(1, n_features + 1):
# ----> 8     for subset in itertools.combinations(X_train.columns, k):
#       9         # Create a subset of the data
#      10         X_train_subset = X_train[list(subset)]
#      11         X_test_subset = X_test[list(subset)]
#
# NameError: name 'itertools' is not defined
